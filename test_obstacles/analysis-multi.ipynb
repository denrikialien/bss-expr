# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./result-multi.csv')

# %%
data = data[data['uptime'] > 0]
data
# Out:
#       rrt sampling  prm sampling  field size  num mobiles  num statics  \
# 0              500            40  [600, 600]           20            0
# 1              500            40  [600, 600]           20            0
# 3              500            40  [600, 600]           20            0
# 4              500            40  [600, 600]           20            0
# 5              500            40  [600, 600]           20            0
# ...            ...           ...         ...          ...          ...
# 2395           500            40  [600, 600]           40           40
# 2396           500            40  [600, 600]           40           40
# 2397           500            40  [600, 600]           40           40
# 2398           500            40  [600, 600]           40           40
# 2399           500            40  [600, 600]           40           40
#
#       num obstacles         obstacles trial  uptime  elapsed time
# 0                 5  ./obstacles.json    #0  551759      0.170705
# 1                 5  ./obstacles.json    #1  664818      0.335835
# 3                 5  ./obstacles.json    #3  587072      0.367282
# 4                 5  ./obstacles.json    #4  663737      0.162703
# 5                 5  ./obstacles.json    #5  565837      0.224268
# ...             ...               ...   ...     ...           ...
# 2395             10  ./obstacles.json   #95  669783      1.028773
# 2396             10  ./obstacles.json   #96  698833      3.349267
# 2397             10  ./obstacles.json   #97  690753      1.761700
# 2398             10  ./obstacles.json   #98  693099      4.146052
# 2399             10  ./obstacles.json   #99  695267      2.771347
#
# [2142 rows x 10 columns]

# %%
data_mean = data.drop(['trial', 'field size'], axis=1).groupby(
  ['num mobiles', 'num statics', 'num obstacles', 'prm sampling'], as_index=False).mean()
data_mean
# Out:
#     num mobiles  num statics  num obstacles  prm sampling  rrt sampling  \
# 0            20            0              5            40         500.0
# 1            20            0             10            40         500.0
# 2            20           20              5            40         500.0
# 3            20           20             10            40         500.0
# 4            20           30              5            40         500.0
# 5            20           30             10            40         500.0
# 6            20           40              5            40         500.0
# 7            20           40             10            40         500.0
# 8            30            0              5            40         500.0
# 9            30            0             10            40         500.0
# 10           30           20              5            40         500.0
# 11           30           20             10            40         500.0
# 12           30           30              5            40         500.0
# 13           30           30             10            40         500.0
# 14           30           40              5            40         500.0
# 15           30           40             10            40         500.0
# 16           40            0              5            40         500.0
# 17           40            0             10            40         500.0
# 18           40           20              5            40         500.0
# 19           40           20             10            40         500.0
# 20           40           30              5            40         500.0
# 21           40           30             10            40         500.0
# 22           40           40              5            40         500.0
# 23           40           40             10            40         500.0
#
#            uptime  elapsed time
# 0   621527.786517      0.264952
# 1   607265.716049      0.336866
# 2   621728.255556      0.264912
# 3   611302.379747      0.428775
# 4   618947.333333      0.284797
# 5   614945.023256      0.407055
# 6   618286.606383      0.254462
# 7   615752.750000      0.387925
# 8   677403.843750      0.780098
# 9   674599.988095      1.018363
# 10  677205.776596      0.754309
# 11  673797.333333      0.960482
# 12  675813.726316      0.765851
# 13  673265.390244      1.211570
# 14  675334.408602      0.760712
# 15  675744.544444      1.044623
# 16  694173.031579      2.086999
# 17  692515.898876      2.622551
# 18  692132.621053      6.933343
# 19  690802.186813      2.657950
# 20  691979.294737      1.795326
# 21  692625.058140      2.639693
# 22  693862.413793      1.903700
# 23  691532.481928      2.651314

# %%
mean5obs = data_mean.groupby('num obstacles').get_group(5)
mean10obs = data_mean.groupby('num obstacles').get_group(10)
mean5obs = mean5obs[mean5obs['uptime'] > 0]
mean10obs = mean10obs[mean10obs['uptime'] > 0]

# %%
mean5obs
# Out:
#     num mobiles  num statics  num obstacles  prm sampling  rrt sampling  \
# 0            20            0              5            40         500.0
# 2            20           20              5            40         500.0
# 4            20           30              5            40         500.0
# 6            20           40              5            40         500.0
# 8            30            0              5            40         500.0
# 10           30           20              5            40         500.0
# 12           30           30              5            40         500.0
# 14           30           40              5            40         500.0
# 16           40            0              5            40         500.0
# 18           40           20              5            40         500.0
# 20           40           30              5            40         500.0
# 22           40           40              5            40         500.0
#
#            uptime  elapsed time
# 0   621527.786517      0.264952
# 2   621728.255556      0.264912
# 4   618947.333333      0.284797
# 6   618286.606383      0.254462
# 8   677403.843750      0.780098
# 10  677205.776596      0.754309
# 12  675813.726316      0.765851
# 14  675334.408602      0.760712
# 16  694173.031579      2.086999
# 18  692132.621053      6.933343
# 20  691979.294737      1.795326
# 22  693862.413793      1.903700

# %%
mean10obs
# Out:
#     num mobiles  num statics  num obstacles  prm sampling  rrt sampling  \
# 1            20            0             10            40         500.0
# 3            20           20             10            40         500.0
# 5            20           30             10            40         500.0
# 7            20           40             10            40         500.0
# 9            30            0             10            40         500.0
# 11           30           20             10            40         500.0
# 13           30           30             10            40         500.0
# 15           30           40             10            40         500.0
# 17           40            0             10            40         500.0
# 19           40           20             10            40         500.0
# 21           40           30             10            40         500.0
# 23           40           40             10            40         500.0
#
#            uptime  elapsed time
# 1   607265.716049      0.336866
# 3   611302.379747      0.428775
# 5   614945.023256      0.407055
# 7   615752.750000      0.387925
# 9   674599.988095      1.018363
# 11  673797.333333      0.960482
# 13  673265.390244      1.211570
# 15  675744.544444      1.044623
# 17  692515.898876      2.622551
# 19  690802.186813      2.657950
# 21  692625.058140      2.639693
# 23  691532.481928      2.651314

# %%
mean10obs['uptime'].values.reshape((3, 4))
# Out:
# array([[607265.71604938, 611302.37974684, 614945.02325581,
#         615752.75      ],
#        [674599.98809524, 673797.33333333, 673265.3902439 ,
#         675744.54444444],
#        [692515.8988764 , 690802.18681319, 692625.05813953,
#         691532.48192771]])

# %%
def plot_uptimes(data):
  uptimes = data['uptime'].values.reshape((3, 4)) / 3600
  num_mobiles= data['num mobiles'].values
  num_statics = data['num statics'].values

  fig = plt.figure(figsize=(8, 8))
  ax = fig.add_subplot(111)
  ax.imshow(uptimes, cmap='GnBu')
  ax.set_xticks(np.arange(uptimes.shape[1]))
  ax.set_xticklabels(['0', '20', '30', '40'])
  ax.set_yticks(np.arange(uptimes.shape[0]))
  ax.set_yticklabels(['20', '30', '40'])
  ax.set_xlabel('Number of static sensors')
  ax.set_ylabel('Number of mobile sensors')
  ax.set_title('Uptime [hour]')
  
  for i in range(uptimes.shape[0]):
    for j in range(uptimes.shape[1]):
      ax.text(j, i, '{:.2f}'.format(uptimes[i][j]), ha='center', va='center', color='black')
  plt.show()

# %%
plot_uptimes(mean5obs)

# %%
plot_uptimes(mean10obs)

# %%
data = pd.read_csv('./result-multi.csv')
data[data['uptime'] == 0].drop(['elapsed time', 'rrt sampling', 'prm sampling', 'field size', 'obstacles', 'trial'], axis=1).groupby(['num mobiles', 'num statics', 'num obstacles']).count()
# Out:
#                                        uptime
# num mobiles num statics num obstacles
# 20          0           5                  11
#                         10                 19
#             20          5                  10
#                         10                 21
#             30          5                   7
#                         10                 14
#             40          5                   6
#                         10                 12
# 30          0           5                   4
#                         10                 16
#             20          5                   6
#                         10                 13
#             30          5                   5
#                         10                 18
#             40          5                   7
#                         10                 10
# 40          0           5                   5
#                         10                 11
#             20          5                   5
#                         10                  9
#             30          5                   5
#                         10                 14
#             40          5                  13
#                         10                 17
