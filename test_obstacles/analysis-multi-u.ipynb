# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./result-multi-u.csv')

# %%
data = data[data['uptime'] > 0]
data
# Out:
#       rrt sampling  prm sampling  field size  num mobiles  num statics  \
# 0              500            40  [600, 600]           20            0
# 1              500            40  [600, 600]           20            0
# 2              500            40  [600, 600]           20            0
# 3              500            40  [600, 600]           20            0
# 4              500            40  [600, 600]           20            0
# ...            ...           ...         ...          ...          ...
# 2395           500            40  [600, 600]           40           40
# 2396           500            40  [600, 600]           40           40
# 2397           500            40  [600, 600]           40           40
# 2398           500            40  [600, 600]           40           40
# 2399           500            40  [600, 600]           40           40
#
#       num obstacles         obstacles trial  uptime  elapsed time
# 0                 5  ./obstacles.json    #0  602665      0.098007
# 1                 5  ./obstacles.json    #1  597677      0.112928
# 2                 5  ./obstacles.json    #2  620139      0.160008
# 3                 5  ./obstacles.json    #3  675779      0.129987
# 4                 5  ./obstacles.json    #4  666848      0.122591
# ...             ...               ...   ...     ...           ...
# 2395             10  ./obstacles.json   #95  706769      1.002024
# 2396             10  ./obstacles.json   #96  700063      1.012351
# 2397             10  ./obstacles.json   #97  706623      0.835836
# 2398             10  ./obstacles.json   #98  686115      0.319745
# 2399             10  ./obstacles.json   #99  672684      0.424268
#
# [2164 rows x 10 columns]

# %%
data_mean = data.drop(['trial', 'field size'], axis=1).groupby(
  ['num mobiles', 'num statics', 'num obstacles', 'prm sampling'], as_index=False).mean()
data_mean
# Out:
#     num mobiles  num statics  num obstacles  prm sampling  rrt sampling  \
# 0            20            0              5            40         500.0
# 1            20            0             10            40         500.0
# 2            20           20              5            40         500.0
# 3            20           20             10            40         500.0
# 4            20           30              5            40         500.0
# 5            20           30             10            40         500.0
# 6            20           40              5            40         500.0
# 7            20           40             10            40         500.0
# 8            30            0              5            40         500.0
# 9            30            0             10            40         500.0
# 10           30           20              5            40         500.0
# 11           30           20             10            40         500.0
# 12           30           30              5            40         500.0
# 13           30           30             10            40         500.0
# 14           30           40              5            40         500.0
# 15           30           40             10            40         500.0
# 16           40            0              5            40         500.0
# 17           40            0             10            40         500.0
# 18           40           20              5            40         500.0
# 19           40           20             10            40         500.0
# 20           40           30              5            40         500.0
# 21           40           30             10            40         500.0
# 22           40           40              5            40         500.0
# 23           40           40             10            40         500.0
#
#            uptime  elapsed time
# 0   643667.434783      0.135716
# 1   634321.197674      0.197762
# 2   646073.793478      0.136705
# 3   643312.600000      0.215251
# 4   648040.247312      0.144684
# 5   639075.074074      0.216066
# 6   659017.500000      0.162077
# 7   654624.436782      0.207183
# 8   688028.212766      0.432490
# 9   686522.235294      0.602090
# 10  690567.731959      0.433884
# 11  687549.292135      0.560775
# 12  690568.565217      0.427766
# 13  690723.413793      0.591680
# 14  692811.333333      0.434906
# 15  688463.625000      0.569439
# 16  699999.279570      0.805698
# 17  698755.439560      1.152743
# 18  702072.947368      0.843553
# 19  700858.847059      1.168511
# 20  703713.946237      0.859799
# 21  701729.777778      1.193431
# 22  704141.224490      0.858861
# 23  702038.689655      1.188791

# %%
mean5obs = data_mean.groupby('num obstacles').get_group(5)
mean10obs = data_mean.groupby('num obstacles').get_group(10)
mean5obs = mean5obs[mean5obs['uptime'] > 0]
mean10obs = mean10obs[mean10obs['uptime'] > 0]

# %%
mean5obs
# Out:
#     num mobiles  num statics  num obstacles  prm sampling  rrt sampling  \
# 0            20            0              5            40         500.0
# 2            20           20              5            40         500.0
# 4            20           30              5            40         500.0
# 6            20           40              5            40         500.0
# 8            30            0              5            40         500.0
# 10           30           20              5            40         500.0
# 12           30           30              5            40         500.0
# 14           30           40              5            40         500.0
# 16           40            0              5            40         500.0
# 18           40           20              5            40         500.0
# 20           40           30              5            40         500.0
# 22           40           40              5            40         500.0
#
#            uptime  elapsed time
# 0   643667.434783      0.135716
# 2   646073.793478      0.136705
# 4   648040.247312      0.144684
# 6   659017.500000      0.162077
# 8   688028.212766      0.432490
# 10  690567.731959      0.433884
# 12  690568.565217      0.427766
# 14  692811.333333      0.434906
# 16  699999.279570      0.805698
# 18  702072.947368      0.843553
# 20  703713.946237      0.859799
# 22  704141.224490      0.858861

# %%
mean10obs
# Out:
#     num mobiles  num statics  num obstacles  prm sampling  rrt sampling  \
# 1            20            0             10            40         500.0
# 3            20           20             10            40         500.0
# 5            20           30             10            40         500.0
# 7            20           40             10            40         500.0
# 9            30            0             10            40         500.0
# 11           30           20             10            40         500.0
# 13           30           30             10            40         500.0
# 15           30           40             10            40         500.0
# 17           40            0             10            40         500.0
# 19           40           20             10            40         500.0
# 21           40           30             10            40         500.0
# 23           40           40             10            40         500.0
#
#            uptime  elapsed time
# 1   634321.197674      0.197762
# 3   643312.600000      0.215251
# 5   639075.074074      0.216066
# 7   654624.436782      0.207183
# 9   686522.235294      0.602090
# 11  687549.292135      0.560775
# 13  690723.413793      0.591680
# 15  688463.625000      0.569439
# 17  698755.439560      1.152743
# 19  700858.847059      1.168511
# 21  701729.777778      1.193431
# 23  702038.689655      1.188791

# %%
mean10obs['uptime'].values.reshape((3, 4))
# Out:
# array([[634321.19767442, 643312.6       , 639075.07407407,
#         654624.43678161],
#        [686522.23529412, 687549.29213483, 690723.4137931 ,
#         688463.625     ],
#        [698755.43956044, 700858.84705882, 701729.77777778,
#         702038.68965517]])

# %%
def plot_uptimes(data):
  uptimes = data['uptime'].values.reshape((3, 4)) / 3600
  num_mobiles= data['num mobiles'].values
  num_statics = data['num statics'].values

  fig = plt.figure(figsize=(8, 8))
  ax = fig.add_subplot(111)
  ax.imshow(uptimes, cmap='GnBu')
  ax.set_xticks(np.arange(uptimes.shape[1]))
  ax.set_xticklabels(['0', '20', '30', '40'])
  ax.set_yticks(np.arange(uptimes.shape[0]))
  ax.set_yticklabels(['20', '30', '40'])
  ax.set_xlabel('Number of static sensors')
  ax.set_ylabel('Number of mobile sensors')
  ax.set_title('Uptime [hour]')
  
  for i in range(uptimes.shape[0]):
    for j in range(uptimes.shape[1]):
      ax.text(j, i, '{:.2f}'.format(uptimes[i][j]), ha='center', va='center', color='black')
  plt.show()

# %%
plot_uptimes(mean5obs)

# %%
plot_uptimes(mean10obs)

# %%
data = pd.read_csv('./result-multi-u.csv')
data[data['uptime'] == 0].drop(['elapsed time', 'rrt sampling', 'prm sampling', 'field size', 'obstacles', 'trial'], axis=1).groupby(['num mobiles', 'num statics', 'num obstacles']).count()
# Out:
#                                        uptime
# num mobiles num statics num obstacles
# 20          0           5                   8
#                         10                 14
#             20          5                   8
#                         10                 10
#             30          5                   7
#                         10                 19
#             40          5                   8
#                         10                 13
# 30          0           5                   6
#                         10                 15
#             20          5                   3
#                         10                 11
#             30          5                   8
#                         10                 13
#             40          5                  13
#                         10                 12
# 40          0           5                   7
#                         10                  9
#             20          5                   5
#                         10                 15
#             30          5                   7
#                         10                 10
#             40          5                   2
#                         10                 13
